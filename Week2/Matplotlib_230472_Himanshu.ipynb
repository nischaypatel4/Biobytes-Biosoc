# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])


ax.plot(x, y)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Title")

plt.show()
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])
plt.ylim(0, 1)
plt.yticks(np.linspace(0, 1, 6))
plt.xlim(0, 1)
plt.xticks(np.linspace(0, 1, 6))
# Out:
# ([<matplotlib.axis.XTick at 0x7d5a281a6bf0>,
#   <matplotlib.axis.XTick at 0x7d5a281a7790>,
#   <matplotlib.axis.XTick at 0x7d5a4050f5e0>,
#   <matplotlib.axis.XTick at 0x7d5a404a3010>,
#   <matplotlib.axis.XTick at 0x7d5a404a0700>,
#   <matplotlib.axis.XTick at 0x7d5a404a3cd0>],
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])
plt.ylim(0, 200)
plt.yticks(np.linspace(0, 200, 5))
plt.xlim(0, 100)
plt.xticks(np.linspace(0, 100, 5))

# Larger Figure Axes 1
ax1.plot(x, y, 'b')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('1')

# Insert Figure Axes 2
ax2.plot(x, y, 'r')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('2 ');

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
plt.ylim(0, 1)
plt.yticks(np.linspace(0, 1, 6))
plt.xlim(0, 1)
plt.xticks(np.linspace(0, 1, 6))

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
plt.ylim(30,50)
plt.yticks(np.linspace(30,50, 5))
plt.xlim(20,22)
plt.xticks(np.linspace(20, 22, 5))

# Larger Figure Axes 1
ax1.plot(x, z, 'b')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('1')


# Insert Figure Axes 2
ax2.plot(x, y, 'r')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('2 ');

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y, 'b--')
plt.xlim(0, 100)
plt.ylim(0, 200)
plt.yticks(np.linspace(0, 200, 9))

plt.subplot(2, 2, 2)
plt.plot(x, z, 'r')

plt.show()

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x, y, 'b--')
plt.xlim(0, 100)
plt.ylim(0, 200)
plt.yticks(np.linspace(0, 200, 9))

plt.subplot(2, 2, 2)
plt.plot(x, z, 'r')

plt.show()

# %% [markdown]
# # Great Job!
