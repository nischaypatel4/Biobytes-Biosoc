# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x ='fare', y = 'age', data = titanic, kind = 'scatter', marginal_kws = dict(bins = 30, fill = True))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(titanic['fare'], bins = 30, kde = False, color = 'red')
plt.xlabel('fare')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = 'class', y = 'age', data = titanic, palette = 'rainbow')
plt.show()
# Out:
# <ipython-input-12-f89d62207ecc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'class', y = 'age', data = titanic, palette = 'rainbow')

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(y = 'age', x = 'class', data = titanic, palette = 'Set2')
plt.show()
# Out:
# <ipython-input-13-3c526d1ab982>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(y = 'age', x = 'class', data = titanic, palette = 'Set2')

# %%
plt.figure(figsize=(8,6))
sns.countplot(data = titanic, x = 'sex', palette = 'muted')
plt.show()
# Out:
# <ipython-input-11-f1f09b851e10>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = titanic, x = 'sex', palette = 'muted')

# %%
plt.figure(figsize = (8,6))
sns.heatmap(data = titanic,palette='coolwarm')
plt.title('titanic.corr()')

# %%
g = sns.FacetGrid(data = titanic, col='sex')
g.map (plt.hist, 'age')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Great Job!
