# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter')

# %%
import matplotlib.pyplot as plt
sns.distplot(titanic['fare'], kde=False, bins=30)
plt.xlim(0,600)
plt.ylim(0,500)
plt.show()
# Out:
# <ipython-input-22-9e4734fb5d81>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'], kde=False, bins=30)

# %%
import matplotlib.pyplot as plt
sns.distplot(titanic['fare'], kde=False, bins=30)
plt.xlim(0,600)
plt.ylim(0,500)
plt.show()

# %%
sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# Out:
# <ipython-input-29-4d082954421f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.swarmplot(x="class", y="age" ,data=titanic,palette='rainbow')
plt.yticks([ 0, 20, 40, 60, 80])
# Out:
# <ipython-input-35-342046ccc34b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="class", y="age" ,data=titanic,palette='rainbow')
# ([<matplotlib.axis.YTick at 0x7dbe0c4fa800>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80')])
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Convert 'sex' column to numerical representation
titanic['sex'] = titanic['sex'].map({'male': 0, 'female': 1})

# Drop non-numerical columns before calculating correlation
numerical_titanic = titanic.select_dtypes(include=['number'])

correlation_matrix = numerical_titanic.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'titanic' is your DataFrame containing the data
# Clean the DataFrame to handle missing values in the 'sex' column
titanic_cleaned = titanic.dropna(subset=['sex'])

# Check if any rows were removed
if titanic_cleaned.shape[0] == 0:
    # Handle missing values in the 'sex' column in a different way
    # For example, you could impute the missing values
    titanic_cleaned = titanic.fillna(value={'sex': 'unknown'})

# Create FacetGrid with 'sex' as row parameter
g = sns.FacetGrid(titanic_cleaned, row="sex")

# Map the histogram plot onto the FacetGrid
g = g.map(plt.hist, "age")

plt.show()

# %% [markdown]
# # Great Job!
