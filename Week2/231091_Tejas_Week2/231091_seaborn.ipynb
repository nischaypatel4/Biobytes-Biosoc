# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x='fare', y='age', data=titanic, kind='scatter')

# %%
sns.histplot(x='fare', data=titanic, color='red')

# %%
sns.boxplot(x="class", y="age", data=titanic, palette='rainbow')
# Out:
# <ipython-input-39-f8a410bf559f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="age", data=titanic, palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.swarmplot(x="class", y="age", data=titanic, palette=['green', 'orange', 'blue'])
# Out:
# <ipython-input-38-67d9747358bc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="class", y="age", data=titanic, palette=['green', 'orange', 'blue'])
# <Axes: xlabel='class', ylabel='age'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex', data=titanic, palette=['blue', 'green'])
# Out:
# <ipython-input-17-f56783f17120>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=titanic, palette=['blue', 'green'])
# <Axes: xlabel='sex', ylabel='count'>

# %%
columns_corr = ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'adult_male', 'alone']
correlation = titanic[columns_corr].corr()
sns.heatmap(correlation, annot=False, cmap="coolwarm")
plt.show()

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

sns.histplot(titanic.loc[titanic['sex'] == 'male']['age'], kde=False, ax=axes[0])
axes[0].set_title('sex=male')
axes[0].set_xlim(0, 80)
axes[0].set_ylim(0, 120)

sns.histplot(titanic.loc[titanic['sex'] == 'female']['age'], kde=False, ax=axes[1])
axes[1].set_title('sex=female')
axes[1].set_xlim(0, 80)
axes[1].set_ylim(0, 120)
# Out:
# (0.0, 120.0)

# %% [markdown]
# # Great Job!
