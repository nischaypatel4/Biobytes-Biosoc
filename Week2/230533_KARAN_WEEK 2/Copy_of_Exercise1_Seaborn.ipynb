# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
g = sns.JointGrid(data=titanic, x="fare", y="age")

g = g.plot(sns.scatterplot, sns.histplot)


plt.show()

# %%
sns.histplot(data=titanic, x='fare', bins=30, kde=False)
plt.xlim(0, 600)
plt.show()

# %%
sns.boxplot(data=titanic, x='class', y='age',palette='rainbow')
plt.show()
# Out:
# <ipython-input-41-721ba9d0ae54>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=titanic, x='class', y='age',palette='rainbow')

# %%
sns.swarmplot(data=titanic, x='class', y='age',hue='class',legend = False,palette='rainbow')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='sex',data=titanic,palette='rainbow')
plt.show()
# Out:
# <ipython-input-54-0eca6be42f39>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=titanic,palette='rainbow')

# %%
sns.heatmap(,cmap='coolwarm',annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-f96930188356> in <cell line: 1>()
# ----> 1 sns.heatmap(titanic.corr(),cmap='coolwarm',annot=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.histplot(titanic[titanic['sex'] == 'male']['age'],
             color='blue', kde=False, bins=12)
plt.ylim(0,120)
plt.title('Male')

plt.subplot(1, 2, 2)
sns.histplot(titanic[titanic['sex'] == 'female']['age'],
             color='blue', kde=False, bins=11)
plt.xlim(0,80)
plt.ylim(0,120)
plt.title('Female')
plt.tight_layout()

# %% [markdown]
# # Great Job!
