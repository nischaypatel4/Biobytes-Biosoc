# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter')

# %%
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter')
plt.xlim(-100, 600)
plt.ylim(-100,80)
# Out:
# (-100.0, 80.0)

# %%
sns.distplot(titanic['fare'],kde=False,bins=30)
# Out:
# <ipython-input-55-968d865734ac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'],kde=False,bins=30)
# <Axes: xlabel='fare'>

# %%
sns.distplot(titanic['fare'],kde=False,bins=30,color='red')
plt.xlim(0, 600)
plt.ylim(0,500)
# Out:
# <ipython-input-56-d7ac4f50c531>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'],kde=False,bins=30,color='red')
# (0.0, 500.0)

# %%
sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# Out:
# <ipython-input-57-4d082954421f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
plt.ylim(0,80)
# Out:
# <ipython-input-58-0d6b43ec08ce>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# (0.0, 80.0)

# %%
sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
# Out:
# <ipython-input-59-d9bb478f893f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
# <Axes: xlabel='class', ylabel='age'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
plt.yticks(range(0 , 100 , 20))
# Out:
# <ipython-input-60-1d2dfb869f0b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
# ([<matplotlib.axis.YTick at 0x79895da75930>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80')])
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex',data=titanic,palette=  {"male": "blue", "female": "orange"})
# Out:
# <ipython-input-70-fb9b27c52e09>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=titanic,palette=  {"male": "blue", "female": "orange"})
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=titanic,palette=  {"male": "blue", "female": "green"})
# Out:
# <ipython-input-71-0b9d5b5054e2>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=titanic,palette=  {"male": "blue", "female": "green"})
# <Axes: xlabel='sex', ylabel='count'>

# %%
titanic.head()
d=['sex','embarked','class','who','deck','embark_town','alive']
df2 = titanic.drop(d, axis=1)
df2.head()
sns.heatmap(df2.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df2.corr(),cmap='coolwarm',vmin=-1, vmax=0.8)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(0.1, 2))
g=sns.FacetGrid(titanic, col="sex",aspect=1.2,height=2)
g.map(plt.hist, "age", bins=10, color='darkblue',alpha=1)

# %%
plt.figure(figsize=(0.1, 2))
g=sns.FacetGrid(titanic, col="sex",aspect=1.2,height=2)
g.map(plt.hist, "age", bins=10, color='blue',alpha=1)
plt.xticks(range(0 , 90 , 10))
plt.yticks(range(0 , 130 , 20))
# Out:
# ([<matplotlib.axis.YTick at 0x79895c03fa60>,
# ...
#  [])

# %% [markdown]
# # Great Job!
