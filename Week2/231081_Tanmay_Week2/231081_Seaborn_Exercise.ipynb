# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter', palette='coolwarm', lw=0)
plt.xlim(-100,600)
# Out:
# (-100.0, 600.0)

# %%
sns.distplot(titanic['fare'],kde=False,bins=30, color='red')
plt.xlim(0, 600)
plt.ylim(0, 500)
# Out:
# <ipython-input-5-659587679a84>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'],kde=False,bins=30, color='red')
# (0.0, 500.0)

# %%
sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
plt.ylim(0,80)
# Out:
# <ipython-input-6-0d6b43ec08ce>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
# (0.0, 80.0)

# %%
import numpy as np
sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
plt.yticks(np.arange(0,100,20))
# Out:
# <ipython-input-7-3454e03840db>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")
# ([<matplotlib.axis.YTick at 0x79b3b1efd300>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80')])
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex',data=titanic, palette='deep')
plt.ylim(0,600)
# Out:
# <ipython-input-8-85a46071603b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=titanic, palette='deep')
# (0.0, 600.0)

# %%
mod_titanic = titanic.drop(['sex','embarked','class','who','deck','embark_town','alive'],axis=1)
cbar_kws = {'ticks':np.arange(-0.8,1,0.4)}
sns.heatmap(mod_titanic.corr(),cmap='coolwarm',vmin=-0.8,vmax=0.8, cbar_kws=cbar_kws)
plt.xticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  [Text(0.5, 0, 'survived'),
#   Text(1.5, 0, 'pclass'),
#   Text(2.5, 0, 'age'),
#   Text(3.5, 0, 'sibsp'),
#   Text(4.5, 0, 'parch'),
#   Text(5.5, 0, 'fare'),
#   Text(6.5, 0, 'adult_male'),
#   Text(7.5, 0, 'alone')])

# %% [markdown]
# # Great Job!
