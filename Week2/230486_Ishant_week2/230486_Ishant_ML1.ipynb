# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ML1_dataset.csv")
data.head(8)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
print(round(data["LotArea"].mean()))
print(round(data["SalePrice"].max()))
# Out:
# 10517
# 755000

# %%
newest_house = data["YearBuilt"].max()
newest_house
# Out:
# 2010

# %% [markdown]
# #### Newest house is not that new: if the reason is explanation1 => The model may still be useful for predicting prices of existing homes, but less reliable for newer constructions........if the reason is explanation 2 => The models trustworthyness is doubtfull as the data is outdated and the model do not know about the current market prices ####

# %%
data['YearBuilt'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: YearBuilt
# Non-Null Count  Dtype
# --------------  -----
# 1460 non-null   int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
y = data.loc[:, ['SalePrice']]
X = data.loc[:, ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]
new_data = pd.concat([X, y], axis=1)

# %%
new_data.isnull().sum()
# Out:
# LotArea         0
# YearBuilt       0
# 1stFlrSF        0
# 2ndFlrSF        0
# FullBath        0
# BedroomAbvGr    0
# TotRmsAbvGrd    0
# SalePrice       0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
model1 = LinearRegression()
model2 = DecisionTreeClassifier()

# %%
model1.fit(X,y)
# Out:
# LinearRegression()

# %%
model2.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
new_data.head(8)
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
# 5    14115       1993       796       566         1             1
# 6    10084       2004      1694         0         2             3
# 7    10382       1973      1107       983         2             3
#
#    TotRmsAbvGrd  SalePrice
# 0             8     208500
# 1             6     181500
# 2             6     223500
# 3             7     140000
# 4             9     250000
# 5             5     143000
# 6             7     307000
# 7             7     200000

# %%
lin_reg_pred = pd.DataFrame(model1.predict(X))
lin_reg_pred.head(8)
# Out:
#                0
# 0  219164.643595
# 1  161876.161280
# 2  217670.671997
# 3  141704.326008
# 4  256836.177254
# 5  204571.362116
# 6  242197.361321
# 7  229004.455445

# %%
dec_tree_pred = pd.DataFrame(model2.predict(X))
dec_tree_pred.head(8)
# Out:
#         0
# 0  208500
# 1  181500
# 2  223500
# 3  140000
# 4  250000
# 5  143000
# 6  307000
# 7  200000

# %% [markdown]
# #### Yeah the linear regression model predicted somewhat deviated values but decission tree model predicted exact value ###
# #### it is because linear regression fits a single line to the training data, and the predictions are on this line, so it is doing underfitting while decission tree is doing overfitting #####

# %%
from sklearn.metrics import mean_absolute_error
mae_lin_reg = mean_absolute_error(y, lin_reg_pred)
mae_dec_tree = mean_absolute_error(y, dec_tree_pred)

# %%
print(mae_lin_reg)
print(mae_dec_tree)
# Out:
# 27667.254099950267
# 61.03013698630137

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1)
model2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dec_tree_pred2 = pd.DataFrame(model2.predict(X_test))
dec_tree_pred2
# Out:
#           0
# 0    186500
# 1    184000
# 2    130000
# 3     92000
# 4    155000
# ..      ...
# 433  246578
# 434  192500
# 435  127500
# 436  181000
# 437  262500
#
# [438 rows x 1 columns]

# %%
y_test
# Out:
#       SalePrice
# 258      231500
# 267      179500
# 288      122000
# 649       84500
# 1233     142000
# ...         ...
# 793      225000
# 631      209500
# 1172     171900
# 1167     173000
# 529      200624
#
# [438 rows x 1 columns]

# %%
mae_dec_tree2 = mean_absolute_error(y_test, dec_tree_pred2)
print(mae_dec_tree2)
# Out:
# 33966.07534246575

# %% [markdown]
# #### Observation: mae increased drastically. It is because earlier we were predicting the data which the model has already seen so it was doing overfitting. But now we are predicting on a new data, so the chances of error has increased. ####

# %% [markdown]
# #### there isn't any general rule whether the MAE is good or not, it depends on the context for which we are training the model. In our context the MAE value is pretty lesser tham the exact outcome values, so our model is satisfactory though it is not very good. ####
