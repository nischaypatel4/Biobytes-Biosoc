# %%
import pandas as pd

# %%
dataset= pd.read_csv("/content/dataset.csv")

# %%
dataset.head(8)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# 3).Avg lot area from above table=10516.828
# Max sale price from above table is 755000.00

# %% [markdown]
# 4).If the explaination is 1 then the data can be used to estimate house prices sold between 2006 and 2010(the range of sold dates in this data)
# If 2 is the explaination then the data might not estimate more recent house prices well as there is no way of taking into account changes in the housing market post 2010.
# The more plausible explaination in no 2.(as there is no data after 2010)

# %%
dataset.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_y=dataset['SalePrice']
df_y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
df_X.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False])

# %%
df_X=dataset[['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd'
]]
df_X.head()
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9

# %%
df_X=df_X.dropna(axis = 0)
df_X.head()
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Model1=LinearRegression()
Model1.fit(df_X,df_y)
# Out:
# LinearRegression()

# %%
print("Making predictions for the following 5 houses:")
print(df_X.head())
print("The predictions are")
print(Model1.predict(df_X.head()))
print('The actual y values are')
print(df_y.head())
Model1_y=df_y.head()
model1_y_pred=Model1.predict(df_X.head())
# Out:
# Making predictions for the following 5 houses:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9
# The predictions are
# [219164.64359536 161876.1612803  217670.6719971  141704.32600794
#  256836.17725416]
# The actual y values are
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor
Model2 = DecisionTreeRegressor(random_state=2)

# %%
Model2.fit(df_X,df_y)
# Out:
# DecisionTreeRegressor(random_state=2)

# %%
print("Making predictions for the following 5 houses:")
print(df_X.head())
print("The predictions are")
print(Model2.predict(df_X.head()))
print('The actual y values are')
print(df_y.head())
Model2_y=df_y.head()
model2_y_pred=Model2.predict(df_X.head())
# Out:
# Making predictions for the following 5 houses:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9
# The predictions are
# [208500. 181500. 223500. 140000. 250000.]
# The actual y values are
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# For model2(decision tree regressor),the predictions for the first 5 houses are exactly correct.

# %%
from sklearn.metrics import mean_absolute_error

predicted_Model1 = Model1.predict(df_X)

mean_absolute_error(df_y, predicted_Model1)
# Out:
# 27667.254099950267

# %%
predicted_Model2 = Model2.predict(df_X)

mean_absolute_error(df_y, predicted_Model2)
# Out:
# 62.35433789954339

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(df_X, df_y, random_state = 1)

# %%
Model3 = DecisionTreeRegressor(random_state=1)
Model3.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print(Model3.predict(test_X))
Model3_test_prediction=Model3.predict(test_X)
print(test_y)
# Out:
# [186500. 184000. 130000.  92000. 164500. 220000. 335000. 144152. 215000.
#  262000. 180000. 121000. 175900. 210000. 248900. 131000. 100000. 149350.
#  235000. 156000. 149900. 265979. 193500. 377500. 100000. 162900. 145000.
#  180000. 582933. 146000. 140000.  91500. 112500. 113000. 145000. 312500.
#  110000. 132000. 305000. 128000. 162900. 115000. 110000. 124000. 215200.
#  180000.  79000. 192000. 282922. 235000. 132000. 325000.  80000. 237000.
#  208300. 100000. 120500. 162000. 153000. 187000. 185750. 335000. 129000.
#  124900. 185750. 133700. 127000. 230000. 146800. 157900. 136000. 153575.
#  335000. 177500. 143000. 202500. 168500. 105000. 305900. 192000. 190000.
#  140200. 134900. 128950. 213000. 108959. 149500. 190000. 175900. 160000.
#  250580. 157000. 120500. 147500. 118000. 117000. 110000. 130000. 148500.
#  148000. 190000. 130500. 127000. 120500. 135000. 168000. 176432. 128000.
#  147000. 260000. 132000. 129500. 171000. 181134. 227875. 189000. 282922.
# ...

# %%
predicted_Model3 = Model3.predict(test_X)

mean_absolute_error(test_y, predicted_Model3)
# Out:
# 29652.931506849316

# %% [markdown]
# Mean absolute error is 62.35 for train data.
# Mean absolute error is 29652.93 for test data.
# This is a significant differrence.
# The mean selling price for houses is 180921.19-thus the mean error is 16.4% of the avg sale value.
